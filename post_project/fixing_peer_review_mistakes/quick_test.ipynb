# %%
alist =  [
    "2024-02-19 15:30:00",
    "2024-02-19 14:30:00",
    "2024-02-19 13:30:00",
    "2024-02-19 12:30:00",
    "2024-02-19 11:30:00"
]

# %%
the_date = '2024-02-19 13:30:00'

# %%
newest_dates = [date for date in alist if date > the_date ]

# %%
print(newest_dates)
# Out:
# ['2024-02-19 15:30:00', '2024-02-19 14:30:00']
